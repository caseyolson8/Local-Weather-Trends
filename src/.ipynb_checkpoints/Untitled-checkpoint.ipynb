# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import helper as hp
plt.style.use('ggplot')

# %%
data_path ='~/Desktop/capstone/data/Denver_1940_2010.csv'
Den = hp.GHCN_Loc(data_path)

# %%
Den.process()

# %%
Den.create_aggregate_df()

# %%
Den.agg_df.head(2)
# Out:
#    Year  PRCP_sum   TMAX_sum   TMIN_sum  SNOW_sum  SNWD_sum
# 0  1948     12.62  63.275956  35.259563      70.8        59
# 1  1949     16.78  63.246575  36.106849      61.0        41

# %%
fig, ax = plt.subplots(1, figsize=(15,10))
Den.stats(ax, 'SNOW_sum')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-ec28dda1549a> in <module>
#       1 fig, ax = plt.subplots(1, figsize=(15,10))
# ----> 2 Den.stats(ax, 'SNOW_sum')
#
# AttributeError: 'GHCN_Loc' object has no attribute 'stats'

# %%
np.ones(len(Y), 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-b1e22ef7cf3d> in <module>
# ----> 1 np.ones(len(Y), 2)
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in ones(shape, dtype, order)
#     190
#     191     """
# --> 192     a = empty(shape, dtype, order)
#     193     multiarray.copyto(a, 1, casting='unsafe')
#     194     return a
#
# TypeError: Cannot interpret '2' as a data type

# %%
fig, ax = plt.subplots(1, figsize=(15,10))

ax.scatter(Den.agg_df['Year'], Den.agg_df['PRCP_sum'])

Den.stats(ax, agg_name)

Y = Den.agg_df['Year']
#Y = data_year_avg(ax, TMIN_d.data_yr, r)

X = np.ones((len(yrs),2))
X[:,0] = yrs
model = OLS(Y, X)
results = model.fit()
params = results.params


X_mdl = np.linspace(1950,2020,100)
Y_mdl = X_mdl*params[0] + params[1]
ax.plot(X_mdl, Y_mdl)

ax.legend();
